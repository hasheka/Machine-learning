# %%
import joblib
import numpy as np

model = joblib.load("student_marks_model.pkl")

# %%
hours = float(input("Enter Hours Studied: "))
attendance = float(input("Enter Attendance %: "))
sleep = float(input("Enter Sleep Hours: "))
prev =  float(input("Enter Previouse Exam Marks: "))
# Out:
# Enter Hours Studied:  8
# Enter Attendance %:  88
# Enter Sleep Hours:  8
# Enter Previouse Exam Marks:  88

# %%
data = np.array([[hours,attendance,sleep,prev]])
prediction = model.predict(data)

print("predicted Final Marks:", prediction[0])
# Out:
# predicted Final Marks: 92.51923743437304
# C:\Users\hashe\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
